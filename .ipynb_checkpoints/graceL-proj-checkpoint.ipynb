# %%
import pandas as pd

firearms_df = pd.read_csv("firearms.tsv", sep="\t")
## count the frequencies of neighborhoods having their firearms removed
neighborhood_count = firearms_df['neighborhood'].value_counts()

#population_df["Neighborhood"] = population_df["Neighborhood"].str.capitalize()
firearms_df["neighborhood"] = firearms_df["neighborhood"].str.capitalize()

pd.set_option('display.max_rows', None)
print(neighborhood_count)
#population_df = pd.read_csv("population.tsv", sep="\t")
#neighborhood_pop = population_df[["Neighborhood", "2020_Total_Population"]]
#merged_df = pd.merge(neighborhood_count, on="Neighborhood")
#print(merged_df)
##print(neighborhood_pop)
# Out:
# Homewood South               252
# South Side Flats             180
# Homewood North               130
# Carrick                      117
# Central Business District    112
# Perry South                  112
# Hazelwood                    112
# East Hills                   109
# Sheraden                     108
# Marshall-Shadeland           108
# Larimer                      107
# Lincoln-Lemington-Belmar     103
# Knoxville                     96
# Middle Hill                   88
# Brighton Heights              82
# Garfield                      80
# Mount Washington              78
# East Liberty                  74
# Bedford Dwellings             69
# Allentown                     67
# Spring Hill-City View         65
# Beechview                     65
# Manchester                    64
# Fineview                      62
# Central Northside             59
# East Allegheny                55
# Homewood West                 53
# Brookline                     51
# ...
